# %% [markdown]
# # Your Title Here
#
# **Jeremy, Pranav**
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(f"./archive/atp_matches_2016.csv")
df.reset_index()
# Out:
#                               level_0                      level_1 level_2  \
# 0                           2016-M020                     Brisbane    Hard
# 1                           2016-M020                     Brisbane    Hard
# 2                           2016-M020                     Brisbane    Hard
# ...                               ...                          ...     ...
# 3001  2016-M-DC-2016-WG-PO-SUI-UZB-01  Davis Cup WG PO: SUI vs UZB    Clay
# 3002  2016-M-DC-2016-WG-PO-SUI-UZB-01  Davis Cup WG PO: SUI vs UZB    Clay
# 3003  2016-M-DC-2016-WG-PO-SUI-UZB-01  Davis Cup WG PO: SUI vs UZB    Clay
#
#       level_3  ... l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced
# 0        32.0  ...      NaN      NaN        NaN        NaN
# 1        32.0  ...      NaN      NaN        NaN        NaN
# 2        32.0  ...      NaN      NaN        NaN        NaN
# ...       ...  ...      ...      ...        ...        ...
# 3001      4.0  ...      NaN      NaN        NaN        NaN
# ...

# %%
""""
merge the csv files together
- add two more columns
    - match id (1 - 53571)
    - year (2000, 2001 ... 2017)
"""

matches_df = pd.DataFrame()
for i in range(2000, 2016):
    tmp = pd.read_csv(f"./archive/atp_matches_{i}.csv")
    tmp['year'] = i
    matches_df = pd.concat([matches_df, tmp], ignore_index=True)

matches_df['match_id'] = np.arange(0, matches_df.shape[0])

# check if merged properly
matches_df

# tmp = pd.read_csv(f"./archive/atp_matches_2016.csv", sep=',', index_col='tourney_id')
# tmp
# Out:
#       tourney_id                 tourney_name surface  draw_size  ...  \
# 0       2000-717                      Orlando    Clay         32  ...
# 1       2000-717                      Orlando    Clay         32  ...
# 2       2000-717                      Orlando    Clay         32  ...
# ...          ...                          ...     ...        ...  ...
# 50176  2015-D081  Davis Cup WG PO: POL vs SVK    Hard          4  ...
# 50177  2015-D081  Davis Cup WG PO: POL vs SVK    Hard          4  ...
# 50178  2015-D081  Davis Cup WG PO: POL vs SVK    Hard          4  ...
#
#       l_bpSaved  l_bpFaced  year  match_id
# 0           4.0        4.0  2000         0
# 1           4.0        9.0  2000         1
# 2           6.0       10.0  2000         2
# ...         ...        ...   ...       ...
# 50176       NaN        NaN  2015     50176
# 50177       NaN        NaN  2015     50177
# 50178       NaN        NaN  2015     50178
#
# [50179 rows x 51 columns]

# %%
import pandas as pd
import numpy as np

from lec_utils import *

# %% [markdown]
# ## Step 1: Introduction

# %%
# TODO

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
""""
clean the NaN values in df

"""

# %%
(
    matches_df
    .plot(kind='hist', x=['w_ace', 'l_ace'], marginal='box', nbins=40,
          title='Title Here')
)

# %%
dropdown_names = widgets.Dropdown(options=np.array(matches_df['winner_name'].values))
dropdown_names
# Out:
# Dropdown(options=('Antony Dupuis', 'Fernando Gonzalez', 'Paradorn Srichaphan', 'Jan Siemerink', 'Jason Stolten…

# %%
player_df = matches_df[(matches_df['winner_name'] == 'Novak Djokovic')]
avg = pd.DataFrame(player_df.groupby('year')['winner_rank_points'].mean())
avg = avg.reset_index()
avg
# Out:
#     year  winner_rank_points
# 0   2004               78.00
# 1   2005              386.36
# 2   2006              885.88
# ..   ...                 ...
# 9   2013            11944.59
# 10  2014            11538.15
# 11  2015            13915.00
#
# [12 rows x 2 columns]

# %%
dropdown_names = widgets.Dropdown(options=np.array(matches_df['winner_name']))
def plot_winner_progress(name):
    player_df = matches_df[(matches_df['winner_name'] == name)]
    avg = pd.DataFrame(player_df.groupby('year')['winner_rank_points'].mean())
    avg = avg.reset_index()
    fig = px.line(
        avg,
        x = 'year',
        y = 'winner_rank_points',
        title = f'{name}: Ranking points over time',
        labels = {
            'year': 'Year',
            'winner_rank_points': 'Rank points'
        }
    )
    fig.show()

def dropdown_names_handler(change):
    if change['name'] == 'value' and (change['new'] != change['old']):
        clear_output()
        display(dropdown_names)
        plot_winner_progress(change['new'])

display(dropdown_names)
plot_winner_progress('Novak Djokovoic')
dropdown_names.observe(dropdown_names_handler)
# Out:
# Dropdown(index=77, options=('Antony Dupuis', 'Fernando Gonzalez', 'Paradorn Srichaphan', 'Jan Siemerink', 'Jas…

# %%
(
    matches_df
    .sample(200, random_state=23)
    .plot(kind='scatter', x=['winner_rank', 'loser_rank'], y='minutes',
          # hover_name='round', size=['winner_rank', 'loser_rank'],
          title='Title Here')
)

# %% [markdown]
# ## Step 3: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 4: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 5: Final Model

# %%
# TODO
